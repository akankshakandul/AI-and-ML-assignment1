# %% [markdown]
# <a href="https://colab.research.google.com/github/akankshakandul/AI-and-ML-assignment1/blob/main/AI%26ML(assignment1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
graph = {
    "A": ["B", "C"],
    "B": ["D", "E"],
    "C": ["F"],
    "D": [],
    "E": ["F"],
    "F": []
}

visited = []
path = []

def dfs(vertex):
    visited.append(vertex)
    path.append(vertex)

    if vertex == goal:
        return

    for neighbour in graph[vertex]:
        if neighbour not in visited:
            dfs(neighbour)

            if goal in path:
                return

    if path and path[-1] != goal:
        path.pop()


start = "A"
goal = "F"

dfs(start)

if goal in path:
    print("DFS Path:", " -> ".join(path))
else:
    print("Goal not found")
# Out:
# DFS Path: A -> B -> E -> F
